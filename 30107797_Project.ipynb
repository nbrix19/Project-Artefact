# %%
# !pip install pandas #Convert the excel file to a dataframe
# !pip install matplotlib #For data visualisation
# !pip install seaborn # For visualisation
# !pip install scikit-learn #For linear regression machine learning alogorithm
# !pip install openpyxl #the pacakage that will path the excel (dataset) file (myDataCombined)
# !pip install numpy statsmodels

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.impute import SimpleImputer
import statsmodels.api as sm

# %%
# Load the Excel file
#file_path = '/content/Data_combined.xlsx'
file_path = '/Users/ARCTe/Desktop/USW/PROJECT/Dissertation/Data_Collection/Dataset_Cholera.xlsx'
data = pd.read_excel(file_path, sheet_name='Sheet1')

# %%
#SCAN COLUMN HEADS
print(data.columns)
print(len(data.columns))
# Out:
# Index(['S/No', 'States', 'CholCase14', 'PopDen14', 'IncLevel14', 'LitLevel14',
#        'D14', 'CFR14', 'CholCase15', 'PopDen15', 'IncLevel15', 'LitLevel15',
#        'D15', 'CFR15', 'CholCase16', 'PopDen16', 'IncLevel16', 'LitLevel16',
#        'D16', 'CFR16', 'CholCase17', 'PopDen17', 'IncLevel17', 'LitLevel17',
#        'D17', 'CFR17', 'CholCase18', 'PopDen18', 'IncLevel18', 'LitLevel18',
#        'D18', 'CFR18', 'CholCase19', 'PopDen19', 'IncLevel19', 'LitLevel19',
#        'D19', 'CFR19', 'CholCase20', 'PopDen20', 'IncLevel20', 'LitLevel20',
#        'D20', 'CFR20', 'CholCase21', 'PopDen21', 'IncLevel21', 'LitLevel21',
#        'D21', 'CFR21', 'CholCase22', 'PopDen22', 'IncLevel22', 'LitLevel22',
#        'D22', 'CFR22', 'CholCase23', 'PopDen23', 'IncLevel23', 'LitLevel23',
#        'D23', 'CFR23'],
#       dtype='object')
# 62

# %%
data.head()
# Out:
#    S/No     States  CholCase14  PopDen14   IncLevel14   LitLevel14  D14  \
# 0     1       ABIA           0   3531408  12400000000  2524956.720    0
# 1     2    ADAMAWA         259   4009037   4900000000  2866461.455   25
# 2     3  AKWA IBOM           0   5121781  15700000000  3662073.415    0
# 3     4    ANAMBRA           0   5226760  10500000000  3737133.400    0
# 4     5     BAUCHI       16898   6107554   4900000000  4366901.110  114
#
#     CFR14  CholCase15  PopDen15  ...   IncLevel22  LitLevel22  D22   CFR22  \
# 0  0.0000          23   3628055  ...  18650000000  2562293.22    1  0.0083
# 1  0.0965           0   4127001  ...  13180000000  3027799.14    3  0.0079
# 2  0.0000           0   5298916  ...  33420000000  3151469.92    5  0.1786
# 3  0.0000         169   5375177  ...  29130000000  3718693.04    0  0.0000
# 4  0.0067         131   6318781  ...  25230000000  5063439.56   38  0.0582
#
#    CholCase23  PopDen23  IncLevel23  LitLevel23  D23   CFR23
# ...

# %%
data.isna().sum()#to check for missing data in the dataset. To point coloumns/cells with no data
# Out:
# S/No           0
# States         0
# CholCase14     0
# PopDen14       0
# IncLevel14     0
#               ..
# PopDen23       0
# IncLevel23    37
# LitLevel23     0
# D23            0
# CFR23          0
# Length: 62, dtype: int64

# %%
data.fillna(0,inplace=True)

# %%
# Top 10 states with the most cholera cases in 2014
top_10_states_2014 = data[['States', 'CholCase14']].sort_values('CholCase14', ascending=False).head(10)

plt.figure(figsize=(8, 3))
sns.barplot(x='States', y='CholCase14', data=top_10_states_2014, palette='viridis')
plt.title("Top 10 States with Most Cholera Cases in 2014", fontsize=14)
plt.xlabel("States", fontsize=12)
plt.ylabel("Number of Cholera Cases", fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\ARCTe\AppData\Local\Temp\ipykernel_12396\1454636765.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='States', y='CholCase14', data=top_10_states_2014, palette='viridis')

# %%
# Top 10 states with the most cholera cases in 2018
top_10_states_2018 = data[['States', 'CholCase18']].sort_values('CholCase18', ascending=False).head(10)

plt.figure(figsize=(8, 3))
sns.barplot(x='States', y='CholCase18', data=top_10_states_2018, palette='viridis')
plt.title("Top 10 States with Most Cholera Cases in 2018", fontsize=14)
plt.xlabel("States", fontsize=12)
plt.ylabel("Number of Cholera Cases", fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\ARCTe\AppData\Local\Temp\ipykernel_12396\2630953750.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='States', y='CholCase18', data=top_10_states_2018, palette='viridis')

# %% [markdown]
# **Cholera Case Trends (2014-2023)**

# %%
# Top 10 states with the most cholera cases in 2023
top_10_states_2023 = data[['States', 'CholCase23']].sort_values('CholCase23', ascending=False).head(10)

plt.figure(figsize=(8, 3))
sns.barplot(x='States', y='CholCase23', data=top_10_states_2023, palette='viridis')
plt.title("Top 10 States with Most Cholera Cases in 2023", fontsize=14)
plt.xlabel("States", fontsize=12)
plt.ylabel("Number of Cholera Cases", fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\ARCTe\AppData\Local\Temp\ipykernel_12396\19960463.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='States', y='CholCase23', data=top_10_states_2023, palette='viridis')

# %%
# Top 10 most populous states in 2014
top_10_most_populated_states_2014 = data[['States', 'PopDen14']].sort_values('PopDen14', ascending=False).head(10)

plt.figure(figsize=(8, 3))
sns.barplot(x='States', y='PopDen14', data=top_10_most_populated_states_2014, palette='viridis')
plt.title("Top 10 Most Populous States in 2014", fontsize=14)
plt.xlabel("States", fontsize=12)
plt.ylabel("Population Density", fontsize=12)
plt.tight_layout()
plt.show()

# %%
# Top 10 most populous states in 2018
top_10_most_populated_states_2018 = data[['States', 'PopDen18']].sort_values('PopDen18', ascending=False).head(10)

plt.figure(figsize=(8, 3))
sns.barplot(x='States', y='PopDen18', data=top_10_most_populated_states_2018, palette='viridis')
plt.title("Top 10 Most Populous States in 2018", fontsize=14)
plt.xlabel("States", fontsize=12)
plt.ylabel("Population Density", fontsize=12)
plt.tight_layout()
plt.show()

# %%
# Top 10 most populous states in 2023
top_10_most_populated_states_2023 = data[['States', 'PopDen23']].sort_values('PopDen23', ascending=False).head(10)

plt.figure(figsize=(8, 3))
sns.barplot(x='States', y='PopDen23', data=top_10_most_populated_states_2023, palette='viridis')
plt.title("Top 10 Most Populous States in 2023", fontsize=14)
plt.xlabel("States", fontsize=12)
plt.ylabel("Population Density", fontsize=12)
plt.tight_layout()
plt.show()

# %%
# Top 10 richest states in 2014
top_10_richest_states_2014 = data[['States', 'IncLevel14']].sort_values('IncLevel14', ascending=False).head(10)

plt.figure(figsize=(8, 3))
sns.barplot(x='States', y='IncLevel14', data=top_10_richest_states_2014, palette='viridis')
plt.title("Top 10 Richest States in 2014", fontsize=14)
plt.xlabel("States", fontsize=12)
plt.ylabel("Population Density", fontsize=12)
plt.tight_layout()
plt.show()

# %%
# Top 10 richest states in 2018
top_10_richest_states_2018 = data[['States', 'IncLevel18']].sort_values('IncLevel18', ascending=False).head(10)

plt.figure(figsize=(8, 3))
sns.barplot(x='States', y='IncLevel18', data=top_10_richest_states_2018, palette='viridis')
plt.title("Top 10 Richest States in 2018", fontsize=14)
plt.xlabel("States", fontsize=12)
plt.ylabel("Income Level", fontsize=12)
plt.tight_layout()
plt.show()

# %%
# Top 10 richest states in 2022
top_10_most_populated_states_2022 = data[['States', 'IncLevel22']].sort_values('IncLevel22', ascending=False).head(10)

plt.figure(figsize=(8, 3))
sns.barplot(x='States', y='IncLevel22', data=top_10_most_populated_states_2022, palette='viridis')
plt.title("Top 10 Richest States in 2022", fontsize=14)
plt.xlabel("States", fontsize=12)
plt.ylabel("Income Level", fontsize=12)
plt.tight_layout()
plt.show()

# %%
# Extract the cholera cases from 2014 to 2023 for all states
years = [f"CholCase{year}" for year in range(14, 24)]  # Column names for cholera cases
cholera_cases = data[['States'] + years]

# Set states as index for easier plotting
cholera_cases.set_index('States', inplace=True)

# Plot the trend of cholera cases over time for all states
plt.figure(figsize=(9, 6))
for state in cholera_cases.index:
    plt.plot(range(2014, 2024), cholera_cases.loc[state], label=state, alpha=0.6)

plt.title("Cholera Cases Trends (2014-2023)", fontsize=14)
plt.xlabel("Year", fontsize=12)
plt.ylabel("Number of Cholera Cases", fontsize=12)
plt.xticks(ticks=range(2014, 2024), labels=range(2014, 2024))
plt.legend(loc='upper right', bbox_to_anchor=(1.15, 1), fontsize=8)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Correlation with Socioeconomic Factors (2022)**

# %%
#Correlation matrix
# Extract relevant columns for 2022
cholera_2022 = data[['CholCase22', 'IncLevel22', 'LitLevel22', 'PopDen22']]

# Calculate the correlation matrix
correlation_matrix = cholera_2022.corr()
print(correlation_matrix)
# Out:
#             CholCase22  IncLevel22  LitLevel22  PopDen22
# CholCase22    1.000000   -0.084795    0.059932  0.059932
# IncLevel22   -0.084795    1.000000    0.539863  0.539863
# LitLevel22    0.059932    0.539863    1.000000  1.000000
# PopDen22      0.059932    0.539863    1.000000  1.000000

# %%
#CORRELATION TEST BETWEEN CHOLERA CASES AND SOCIOECONOMIC FACTORS

# Extract relevant columns for 2019
cholera_2019 = data[['CholCase19', 'IncLevel19', 'LitLevel19', 'PopDen19']]

# Calculate the correlation matrix
correlation_matrix = cholera_2019.corr()

# Plot the correlation matrix as a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", center=0, linewidths=1, linecolor='white')
plt.title("Correlation Between Cholera Cases and Socioeconomic Factors (2019)", fontsize=14)
plt.tight_layout()
plt.show()

# %%
#CORRELATION TEST BETWEEN CHOLERA CASES AND SOCIOECONOMIC FACTORS

# Extract relevant columns for 2021
cholera_2021 = data[['CholCase21', 'IncLevel21', 'LitLevel21', 'PopDen21']]

# Calculate the correlation matrix
correlation_matrix = cholera_2021.corr()

# Plot the correlation matrix as a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", center=0, linewidths=1, linecolor='white')
plt.title("Correlation Between Cholera Cases and Socioeconomic Factors (2021)", fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Case Fatality Rate (CFR) Analysis**

# %%
import numpy as np #To convert data to a  matrix/vector

# Extract CFR columns for the years 2014-2023
cfr_years = [f"CFR{i}" if i != 0 else "CFR" for i in range(14,24)]  # CFR columns in the dataset
cfr_data = data[['States'] + cfr_years]

# Convert all values in CFR columns to numeric, replace errors with NaN
for col in cfr_years:
    cfr_data[col] = pd.to_numeric(cfr_data[col], errors='coerce')

# Set states as index for easier plotting
cfr_data.set_index('States', inplace=True)

# Plot heatmap of CFR over the years
plt.figure(figsize=(10, 8))
sns.heatmap(cfr_data, annot=True, cmap="YlGnBu", linewidths=0.5)
plt.title("Case Fatality Rate (CFR) by States (2014-2023)", fontsize=14)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\ARCTe\AppData\Local\Temp\ipykernel_12396\3747225226.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cfr_data[col] = pd.to_numeric(cfr_data[col], errors='coerce')

# %% [markdown]
# **Deaths (D) Over Time**

# %%
# Extract death columns for each year
death_years = [f"D{i}" if i != 0 else "D" for i in range(14,24)]  # Death columns in the dataset
death_data = data[['States'] + death_years]
death_data.set_index('States', inplace=True)
# Plot trends in deaths over the years
plt.figure(figsize=(10, 6))
for state in death_data.index:
    plt.plot(range(2014, 2024), death_data.loc[state], label=state, alpha=0.6)

plt.title("Cholera Death Trends (2014-2023)", fontsize=14)
plt.xlabel("Year", fontsize=12)
plt.ylabel("Number of Deaths", fontsize=12)
plt.xticks(ticks=range(2014, 2024), labels=range(2014, 2024))
plt.legend(loc='upper right', bbox_to_anchor=(1.15, 1), fontsize=8)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ** Cholera Cases Distribution per State (Boxplot)**

# %%
# Extract cholera case data for boxplot
cholera_cases = data[['States'] + years]

plt.figure(figsize=(8, 6))
sns.boxplot(data=cholera_cases.drop('States', axis=1), palette='Set2')
plt.title("Distribution of Cholera Cases Across Years (2014-2023)", fontsize=14)
plt.xlabel("Year", fontsize=12)
plt.ylabel("Number of Cholera Cases", fontsize=12)
plt.xticks(ticks=range(10), labels=range(2014, 2024))
plt.tight_layout()
plt.show()

# %% [markdown]
# **Population Density vs Cholera Cases (2023)**

# %%
# Scatter plot for population density vs cholera cases in 2023
plt.figure(figsize=(8, 6))
sns.scatterplot(x='PopDen23', y='CholCase23', data=data, hue='States', palette='tab10', s=100)
plt.title("Population Density vs Cholera Cases (2023)", fontsize=14)
plt.xlabel("Population Density (2023)", fontsize=12)
plt.ylabel("Cholera Cases (2023)", fontsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Trend of Total Cholera Cases Across Nigeria (2014-2023)**

# %%
years = range(2014, 2024)

# Convert all cholera case columns to numeric, replacing any errors with NaN
for year in years:
    column_name = f'CholCase{str(year)[-2:]}'  
    cholera_cases.loc[:, column_name] = pd.to_numeric(cholera_cases[column_name], errors='coerce')

# Calculate total cholera cases for each year
total_cholera_cases = [cholera_cases[f'CholCase{str(year)[-2:]}'].sum() for year in years]

# Plot total cholera cases across Nigeria over the years
plt.plot(years, total_cholera_cases, marker="o", linestyle="-", color="b")
plt.title("Total Cholera Cases in Nigeria (2014-2024)", fontsize=14)
plt.xlabel("Year", fontsize=12)
plt.ylabel("Total Cholera Cases", fontsize=12)
plt.xticks(ticks=years, labels=years)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Year-on-Year Percentage Change in Cholera Cases**

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# Ensure all cholera case columns are numeric
for year in years:
    column_name = f'CholCase{str(year)[-2:]}'  
    cholera_cases.loc[:, column_name] = pd.to_numeric(cholera_cases[column_name], errors='coerce')
    

# Sum cholera cases across all states for each year
total_cholera_cases = cholera_cases[years].sum()

# Calculate year-on-year percentage change
pct_change = total_cholera_cases.pct_change() * 100

# Increase the figure size for better visibility
plt.figure(figsize=(8, 6))

# Define a color gradient for the bars based on total cases
colors = plt.cm.coolwarm(np.linspace(0.2, 0.8, len(total_cholera_cases)))

# Create the bar plot
bars = plt.bar(range(2014, 2024), total_cholera_cases, color=colors, alpha=0.85, edgecolor='black', width=0.6)

# Loop through bars and annotate them with total cases and percentage change
for i, bar in enumerate(bars):
    height = bar.get_height()

    # Annotate total cholera cases inside the bars, placing based on height for readability
    if height > 5000:
        plt.text(bar.get_x() + bar.get_width() / 2, height - 4000, f'{int(height):,}',
                 ha='center', va='top', fontsize=10, color='white', fontweight='bold')
    else:
        plt.text(bar.get_x() + bar.get_width() / 2, height + 500, f'{int(height):,}',
                 ha='center', va='bottom', fontsize=10, color='black', fontweight='bold')

    # Annotate percentage change above the bars
    if i > 0:  # Skip the first bar (no % change for 2014)
        prev_height = total_cholera_cases[i-1]
        if prev_height == 0:  # Handle division by zero
            plt.text(bar.get_x() + bar.get_width() / 2, height + 2000,
                     'New cases', ha='center', va='bottom', fontsize=10,
                     fontweight='bold', color='purple')
        else:
            change = pct_change[i]
            if not pd.isna(change):  # Only annotate valid percentage changes
                # Use color coding: green for increase, red for decrease
                color = 'green' if change > 0 else 'red'
                plt.text(bar.get_x() + bar.get_width() / 2, height + 2000,
                         f'{change:+.2f}%', ha='center', va='bottom', fontsize=10,
                         fontweight='bold', color=color)

# Customize plot appearance
plt.title("Total Cholera Cases and Year-on-Year % Change (2014-2023)", fontsize=16, fontweight='bold', color='darkblue')
plt.xlabel("Year", fontsize=12)
plt.ylabel("Total Cholera Cases", fontsize=12)

# Set x-axis ticks and labels
plt.xticks(ticks=range(2014, 2024), labels=range(2014, 2024))

# Add gridlines for better readability
plt.grid(axis='y', linestyle='--', alpha=0.6)

# Set y-axis limits to create space for annotations
plt.ylim(0, total_cholera_cases.max() + 15000)  # Add some space above the bars for annotations

# Apply tight layout to ensure proper spacing
plt.tight_layout()

# Display the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[148], line 12
#       8     cholera_cases.loc[:, column_name] = pd.to_numeric(cholera_cases[column_name], errors='coerce')
#      11 # Sum cholera cases across all states for each year
# ---> 12 total_cholera_cases = cholera_cases[years].sum()
#      14 # Calculate year-on-year percentage change
#      15 pct_change = total_cholera_cases.pct_change() * 100
#
# File c:\Users\ARCTe\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# ...

# %%
import matplotlib.pyplot as plt

# Define the years of interest
years = range(2014, 2024)  # Corresponds to the years 2014-2023

# Extract Cholera cases, Population Density, Income Level, and Literacy Level from the dataframe for each year
cholera_cases = [f'CholCase{year % 100}' for year in years]  # Using 14, 15, ..., 23
pop_density = [f'PopDen{year % 100}' for year in years]
income_level = [f'IncLevel{year % 100}' for year in years]
literacy_level = [f'LitLevel{year % 100}' for year in years]

# Sum cholera cases and calculate the mean of population density, income level, and literacy level for each year
total_cholera_cases = data[cholera_cases].sum()
avg_pop_density = data[pop_density].mean()
avg_income_level = data[income_level].mean()
avg_literacy_level = data[literacy_level].mean()

# Create the figure and the axes
fig, ax1 = plt.subplots(figsize=(10, 8))

# Plot Cholera Cases as a bar plot
ax1.bar(years, total_cholera_cases, color='blue', alpha=0.6, label='Cholera Cases')
ax1.set_xlabel('Year', fontsize=14)
ax1.set_ylabel('Total Cholera Cases', color='blue', fontsize=14)

# Set the x-axis ticks to show every year explicitly
ax1.set_xticks(years)
ax1.set_xticklabels([str(year) for year in years], rotation=45, ha='right')

# Create a second y-axis for Population Density
ax2 = ax1.twinx()
ax2.plot(years, avg_pop_density, color='green', marker='o', linestyle='-', label='Population Density', linewidth=2)
ax2.set_ylabel('Population Density (PopDen)', color='green', fontsize=14)

# Create a third y-axis for Literacy Level
ax3 = ax1.twinx()
ax3.spines['right'].set_position(('outward', 60))  # Adjust the position of the third axis
ax3.plot(years, avg_literacy_level, color='red', marker='s', linestyle='--', label='Literacy Level', linewidth=2)
ax3.set_ylabel('Literacy Level (LitLevel)', color='red', fontsize=14)
ax3.spines['right'].set_visible(False)  # Hide the spine (line) for the third axis

# Hide the ticks and labels for the third y-axis
ax3.tick_params(right=False)  # Hide tick marks
ax3.set_yticklabels([])  # Hide tick labels

# Create a fourth y-axis for Income Level
ax4 = ax1.twinx()
ax4.spines['right'].set_position(('outward', 120))  # Adjust the position of the fourth axis
ax4.plot(years, avg_income_level, color='orange', marker='^', linestyle='-.', label='Income Level', linewidth=2)
ax4.set_ylabel('Income Level (IncLevel)', color='orange', fontsize=14)
ax4.spines['right'].set_visible(False)  # Hide the spine (line) for the fourth axis

# Hide the ticks and labels for the fourth y-axis
ax4.tick_params(right=False)  # Hide tick marks
ax4.set_yticklabels([])  # Hide tick labels

# Combine all legends into one horizontal legend at the top
lines, labels = [], []
for ax in [ax1, ax2, ax3, ax4]:
    ax_lines, ax_labels = ax.get_legend_handles_labels()
    lines.extend(ax_lines)
    labels.extend(ax_labels)

fig.legend(lines, labels, loc='upper center', bbox_to_anchor=(0.5, 1.1), ncol=4, fontsize=12)

# Adjust layout for better spacing and visibility
fig.tight_layout()

# Show the plot
plt.title('Cholera Cases vs Population Density, Literacy Level, and Income Level (2014-2023)', fontsize=16)
plt.show()

# %%
import matplotlib.pyplot as plt

# Define the years of interest
years = range(2014, 2024)  # Corresponds to the years 2014-2023

# Extract Cholera cases, Population Density, Income Level, and Literacy Level from the dataframe for each year
cholera_cases = [f'CholCase{year % 100}' for year in years]
pop_density = [f'PopDen{year % 100}' for year in years]
income_level = [f'IncLevel{year % 100}' for year in years]
literacy_level = [f'LitLevel{year % 100}' for year in years]

# Sum cholera cases and calculate the mean of population density, income level, and literacy level for each year
total_cholera_cases = data[cholera_cases].sum()
avg_pop_density = data[pop_density].mean()
avg_income_level = data[income_level].mean()
avg_literacy_level = data[literacy_level].mean()

# Create a figure for the scatter plots
fig, axs = plt.subplots(1, 3, figsize=(18, 6), sharey=True)

# Scatter plot: Cholera Cases vs Population Density
axs[0].scatter(avg_pop_density, total_cholera_cases, color='blue')
axs[0].set_title('Cholera Cases vs Population Density')
axs[0].set_xlabel('Population Density (PopDen)')
axs[0].set_ylabel('Total Cholera Cases')

# Scatter plot: Cholera Cases vs Literacy Level
axs[1].scatter(avg_literacy_level, total_cholera_cases, color='green')
axs[1].set_title('Cholera Cases vs Literacy Level')
axs[1].set_xlabel('Literacy Level')

# Scatter plot: Cholera Cases vs Income Level
axs[2].scatter(avg_income_level, total_cholera_cases, color='red')
axs[2].set_title('Cholera Cases vs Income Level')
axs[2].set_xlabel('Income Level')

# Adjust layout for better spacing
fig.tight_layout()

# Show the plot
plt.show()

# %%
def average_value(values):
    total = 0
    for value in values:
        total += value
    avg = total / len(values)
    return avg 

average_pop_density = average_value(avg_pop_density)
average_Inc_Level = average_value(avg_income_level)
average_Lit_Level = average_value(avg_literacy_level)
print(average_pop_density)
print(average_Inc_Level)
print(average_Lit_Level)
# Out:
# 5423608.143243243
# 27728540540.54054
# 3896624.5915810815

# %%
# Reshape the data to long format
popden_long = data.melt(value_vars=['PopDen14', 'PopDen15', 'PopDen16', 'PopDen17', 'PopDen18', 'PopDen19', 'PopDen20', 'PopDen21', 'PopDen22', 'PopDen23'],
                        var_name='Year', value_name='PopDen')
cholcase_long = data.melt(value_vars=['CholCase14', 'CholCase15', 'CholCase16', 'CholCase17', 'CholCase18', 'CholCase19', 'CholCase20', 'CholCase21', 'CholCase22', 'CholCase23'],
                          var_name='Year', value_name='CholCase')

# Combine the reshaped data
data_long = pd.concat([popden_long['PopDen'], cholcase_long['CholCase']], axis=1)

# Define the dependent and independent variables
X = data_long['PopDen']
y = data_long['CholCase']

# Add a constant to the independent variables
X = sm.add_constant(X)

# Fit the model
model = sm.OLS(y, X).fit()

# Get the summary of the model
print(model.summary())

# Create a scatter plot
plt.scatter(data_long['PopDen'], data_long['CholCase'], color='blue', label='Data points')

# Fit a linear regression line
coefficients = np.polyfit(data_long['PopDen'], data_long['CholCase'], 1)
poly = np.poly1d(coefficients)
plt.plot(data_long['PopDen'], poly(data_long['PopDen']), color='red', label='Fit line')
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               CholCase   R-squared:                       0.037
# Model:                            OLS   Adj. R-squared:                  0.034
# Method:                 Least Squares   F-statistic:                     14.06
# Date:                Fri, 06 Sep 2024   Prob (F-statistic):           0.000205
# Time:                        19:17:40   Log-Likelihood:                -3371.0
# No. Observations:                 370   AIC:                             6746.
# Df Residuals:                     368   BIC:                             6754.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -304.2366    271.939     -1.119      0.264    -838.986     230.513
# ...

# %%
# Reshape the data to long format
inclevel_long = data.melt(value_vars=['IncLevel14', 'IncLevel15', 'IncLevel16', 'IncLevel17', 'IncLevel18', 'IncLevel19', 'IncLevel20', 'IncLevel21', 'IncLevel22', 'IncLevel23'],
                          var_name='Year', value_name='IncLevel')
cholcase_long = data.melt(value_vars=['CholCase14', 'CholCase15', 'CholCase16', 'CholCase17', 'CholCase18', 'CholCase19', 'CholCase20', 'CholCase21', 'CholCase22', 'CholCase23'],
                          var_name='Year', value_name='CholCase')

# Combine the reshaped data
data_long = pd.concat([inclevel_long['IncLevel'], cholcase_long['CholCase']], axis=1)

# Define the dependent and independent variables
X = data_long['IncLevel']
y = data_long['CholCase']

# Add a constant to the independent variables
X = sm.add_constant(X)

# Fit the model
model = sm.OLS(y, X).fit()

# Get the summary of the model
print(model.summary())

# Create a scatter plot
plt.scatter(data_long['IncLevel'], data_long['CholCase'], color='blue', label='Data points')

# Fit a linear regression line
coefficients = np.polyfit(data_long['IncLevel'], data_long['CholCase'], 1)
poly = np.poly1d(coefficients)
plt.plot(data_long['IncLevel'], poly(data_long['IncLevel']), color='red', label='Fit line')

# Annotate the plot with R-squared value and p-value
R_squared = model.rsquared
p_value = model.f_pvalue
plt.text(min(data_long['IncLevel']), max(data_long['CholCase']) - 10, f'R-squared: {R_squared:.4f}', fontsize=12)
plt.text(min(data_long['IncLevel']), max(data_long['CholCase']) - 20, f'p-value: {p_value:.2e}', fontsize=12)

# Add labels and title
plt.xlabel('Income Level (IncLevel)')
plt.ylabel('Cholera Cases (CholCase)')
plt.title('Scatter Plot of Income Level vs Cholera Cases')
plt.legend()

# Show the plot
plt.show()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               CholCase   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.003
# Method:                 Least Squares   F-statistic:                   0.07940
# Date:                Fri, 06 Sep 2024   Prob (F-statistic):              0.778
# Time:                        19:21:53   Log-Likelihood:                -3377.9
# No. Observations:                 370   AIC:                             6760.
# Df Residuals:                     368   BIC:                             6768.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        635.0528    126.220      5.031      0.000     386.851     883.255
# ...

# %%
import numpy as np

# Reshape the data to long format
litlevel_long = data.melt(value_vars=['LitLevel14', 'LitLevel15', 'LitLevel16', 'LitLevel17', 'LitLevel18', 'LitLevel19', 'LitLevel20', 'LitLevel21', 'LitLevel22', 'LitLevel23'],
                          var_name='Year', value_name='LitLevel')
cholcase_long = data.melt(value_vars=['CholCase14', 'CholCase15', 'CholCase16', 'CholCase17', 'CholCase18', 'CholCase19', 'CholCase20', 'CholCase21', 'CholCase22', 'CholCase23'],
                          var_name='Year', value_name='CholCase')

# Combine the reshaped data
data_long = pd.concat([litlevel_long['LitLevel'], cholcase_long['CholCase']], axis=1)

# Define the dependent and independent variables
X = data_long['LitLevel']
y = data_long['CholCase']

# Add a constant to the independent variables
X = sm.add_constant(X)

# Fit the model
model = sm.OLS(y, X).fit()

# Get the summary of the model
print(model.summary())


# Create a scatter plot
plt.scatter(data_long['LitLevel'], data_long['CholCase'], color='blue', label='Data points')

# Fit a linear regression line
coefficients = np.polyfit(data_long['LitLevel'], data_long['CholCase'], 1)
poly = np.poly1d(coefficients)
plt.plot(data_long['LitLevel'], poly(data_long['LitLevel']), color='red', label='Fit line')

# Annotate the plot with R-squared value and p-value
R_squared = model.rsquared
p_value = model.f_pvalue
plt.text(min(data_long['LitLevel']), max(data_long['CholCase']) - 10, f'R-squared: {R_squared:.4f}', fontsize=12)
plt.text(min(data_long['LitLevel']), max(data_long['CholCase']) - 20, f'p-value: {p_value:.2e}', fontsize=12)

# Add labels and title
plt.xlabel('Literacy Level (LitLevel)')
plt.ylabel('Cholera Cases (CholCase)')
plt.title('Scatter Plot of Literacy Level vs Cholera Cases')
plt.legend()

# Show the plot
plt.show()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               CholCase   R-squared:                       0.048
# Model:                            OLS   Adj. R-squared:                  0.046
# Method:                 Least Squares   F-statistic:                     18.59
# Date:                Fri, 06 Sep 2024   Prob (F-statistic):           2.08e-05
# Time:                        19:26:29   Log-Likelihood:                -3368.8
# No. Observations:                 370   AIC:                             6742.
# Df Residuals:                     368   BIC:                             6749.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -434.6897    269.918     -1.610      0.108    -965.466      96.086
# ...

# %%
# Reshape the data to long format
popden_long = data.melt(value_vars=['PopDen14', 'PopDen15', 'PopDen16', 'PopDen17', 'PopDen18', 'PopDen19', 'PopDen20', 'PopDen21', 'PopDen22', 'PopDen23'],
                        var_name='Year', value_name='PopDen')
litlevel_long = data.melt(value_vars=['LitLevel14', 'LitLevel15', 'LitLevel16', 'LitLevel17', 'LitLevel18', 'LitLevel19', 'LitLevel20', 'LitLevel21', 'LitLevel22', 'LitLevel23'],
                          var_name='Year', value_name='LitLevel')
inclevel_long = data.melt(value_vars=['IncLevel14', 'IncLevel15', 'IncLevel16', 'IncLevel17', 'IncLevel18', 'IncLevel19', 'IncLevel20', 'IncLevel21', 'IncLevel22', 'IncLevel23'],
                          var_name='Year', value_name='IncLevel')
cholcase_long = data.melt(value_vars=['CholCase14', 'CholCase15', 'CholCase16', 'CholCase17', 'CholCase18', 'CholCase19', 'CholCase20', 'CholCase21', 'CholCase22', 'CholCase23'],
                          var_name='Year', value_name='CholCase')

# Combine the reshaped data
data_long = pd.concat([popden_long['PopDen'], litlevel_long['LitLevel'], inclevel_long['IncLevel'], cholcase_long['CholCase']], axis=1)

# Define the dependent and independent variables
X = data_long[['PopDen', 'LitLevel', 'IncLevel']]
y = data_long['CholCase']

# Add a constant to the independent variables
X = sm.add_constant(X)

# Fit the model
model = sm.OLS(y, X).fit()

# Get the summary of the model
print(model.summary())

#---------------------------------------
# Combine the reshaped data
data_long = pd.concat([popden_long['PopDen'], litlevel_long['LitLevel'], inclevel_long['IncLevel'], cholcase_long['CholCase']], axis=1)

# Define the dependent and independent variables
X = data_long[['PopDen', 'LitLevel', 'IncLevel']]
y = data_long['CholCase']

# Add a constant to the independent variables
X = sm.add_constant(X)

# Fit the model
model = sm.OLS(y, X).fit()

# Plotting
plt.figure(figsize=(10, 6))
sns.scatterplot(x='PopDen', y='CholCase', data=data_long, label='Data Points')
sns.regplot(x='PopDen', y='CholCase', data=data_long, scatter=False, label='Regression Line', color='red')
plt.xlabel('Population density + Income level + Literacy level')
plt.ylabel('Cholera Cases')
plt.title('Scatter plot for combined independent variables')
plt.legend()
plt.show()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               CholCase   R-squared:                       0.086
# Model:                            OLS   Adj. R-squared:                  0.078
# Method:                 Least Squares   F-statistic:                     11.44
# Date:                Thu, 05 Sep 2024   Prob (F-statistic):           3.44e-07
# Time:                        23:02:03   Log-Likelihood:                -3361.3
# No. Observations:                 370   AIC:                             6731.
# Df Residuals:                     366   BIC:                             6746.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -629.6090    280.053     -2.248      0.025   -1180.324     -78.894
# ...
